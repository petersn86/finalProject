# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
wine = pd.read_csv("C:\\Users\\bubbl\\Downloads\WineAverages.csv")

# %%
plt.bar(wine.Alcohol.keys(), wine.Alcohol, edgecolor='black', width = 0.4)
plt.title("Alcohol")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.MalicAcid.keys(), wine.MalicAcid, edgecolor='black', width = 0.4)
plt.title("Malic Acid")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.Ash.keys(), wine.Ash, edgecolor='black', width = 0.4)
plt.title("Ash")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.AcalinityofAsh.keys(), wine.AcalinityofAsh, edgecolor='black', width = 0.4)
plt.title("Acalinity of Ash")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.Magnesium.keys(), wine.Magnesium, edgecolor='black', width = 0.4)
plt.title("Magnesium")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.TotalPhenols.keys(), wine.TotalPhenols, edgecolor='black', width = 0.4)
plt.title("Total Phenols")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.Flavanoids.keys(), wine.Flavanoids, edgecolor='black', width = 0.4)
plt.title("Flavanoids")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.NonflavanoidPhenols.keys(), wine.NonflavanoidPhenols, edgecolor='black', width = 0.4)
plt.title("Nonflavanoid Phenols")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.Proanthocyanins.keys(), wine.Proanthocyanins, edgecolor='black', width = 0.4)
plt.title("Proanthocyanins")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
plt.bar(wine.Proline.keys(), wine.Proline, edgecolor='black', width = 0.4)
plt.title("Proline")
plt.xlabel("Cultivators")
# Out:
# Text(0.5, 0, 'Cultivators')

# %%
rsd = pd.read_csv("C:\\Users\\bubbl\\Downloads\WineRelativeStandardDeviation.csv")

# %%
plt.bar(rsd.RSDL.keys(), rsd.RSDL, edgecolor='black', width = 0.4)
plt.title("Relative Standard Deviation (%)")
plt.xlabel("Variables")
# Out:
# Text(0.5, 0, 'Variables')
